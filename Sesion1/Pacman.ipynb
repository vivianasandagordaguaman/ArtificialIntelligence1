# %% [markdown]
# ## PACMAN
# El material y el código de este proyecto es una versión traducida y completada del curso cs188 de la Universidad de Berkeley. Credits: The projects were developed by John DeNero, Dan Klein, Pieter Abbeel, and many others.

# %% [markdown]
# Después de descargar el código (search.zip), descomprimirlo y cambiar al directorio, debería poder jugar un juego de Pacman escribiendo lo siguiente en la línea de comando. Puedes ejecutarlo directamente desde jupyter notebook usando !

# %%
cd search
# Out:
# C:\Datos\Clases\IA\IAIC\2122\practicas\sesion1\search

# %%
# !python pacman.py
# No estamos indicando el comportamiento del pacman. Por defecto PACMAN manual (teclado) se puede elegir qué agente controla al pacman
# usando el parámetro –p.  Los fantasmas tienen por defecto un comportamiento random
# Out:
# Pacman died! Score: -457
# Average Score: -457.0
# Scores:        -457.0
# Win Rate:      0/1 (0.00)
# Record:        Loss

# %% [markdown]
# Pacman vive en un mundo azul brillante de pasillos serpenteantes y deliciosas golosinas redondas. Navegar por este mundo de manera eficiente será el primer paso de Pacman para dominar su dominio.
#
# El agente más simple de searchAgents.py se llama GoWestAgent, que siempre va hacia el oeste (un agente reflejo trivial). Este agente puede ganar ocasionalmente aunque nunca gira.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# !python pacman.py --layout testMaze --pacman GoWestAgent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Al cambiar el laberinto nunca puede ganar. Para salir puedes usar CTRL-c en el terminal.

# %%
python pacman.py --layout tinyMaze --pacman GoWestAgent

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Las opciones y parámetros se pueden expresar en formato largo (--layout) o corto (-l). Se puede ver una lista de todas las opciones y valores por defecto con:

# %%
# !python pacman.py -h
# Out:
# Usage:
#     USAGE:      python pacman.py <options>
#     EXAMPLES:   (1) python pacman.py
#                     - starts an interactive game
#                 (2) python pacman.py --layout smallClassic --zoom 2
#                 OR  python pacman.py -l smallClassic -z 2
#                     - starts an interactive game on a smaller board, zoomed in
#
#
# Options:
#   -h, --help            show this help message and exit
#   -n GAMES, --numGames=GAMES
#                         the number of GAMES to play [Default: 1]
#   -l LAYOUT_FILE, --layout=LAYOUT_FILE
#                         the LAYOUT_FILE from which to load the map layout
#                         [Default: mediumClassic]
#   -p TYPE, --pacman=TYPE
#                         the agent TYPE in the pacmanAgents module to use
#                         [Default: KeyboardAgent]
#   -t, --textGraphics    Display output as text only
#   -q, --quietTextGraphics
#                         Generate minimal output and no graphics
# ...

# %% [markdown]
# En la siguiente sesión probaremos un agente que busca un punto de comida usando búsqueda en profundidad y búsqueda en anchura.
# Prueba que el agente de búsqueda funciona correctamente usando:

# %%
python pacman.py -l tinyMaze -p SearchAgent -a fn=tinyMazeSearch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Piensa qué estrategias de toma de decisiones necesita el PACMAM. Haz una lista de cuales serían las percepciones y las actuaciones necesarias.
